# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
excel_file_path = "dbfs:/FileStore/tables/pokemon_data.xlsx"
df = spark.read \
.format("com.crealytics.spark.excel") \
.option("header", "true") \
.option("inferSchema", "true") \
.load(excel_file_path)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>#</th><th>Name</th><th>Type 1</th><th>Type 2</th><th>HP</th><th>Attack</th><th>Defense</th><th>Sp. Atk</th><th>Sp. Def</th><th>Speed</th><th>Generation</th><th>Legendary</th></tr></thead><tbody><tr><td>1.0</td><td>Bulbasaur</td><td>Grass</td><td>Poison</td><td>45.0</td><td>49.0</td><td>49.0</td><td>65.0</td><td>65.0</td><td>45.0</td><td>1.0</td><td>false</td></tr><tr><td>2.0</td><td>Ivysaur</td><td>Grass</td><td>Poison</td><td>60.0</td><td>62.0</td><td>63.0</td><td>80.0</td><td>80.0</td><td>60.0</td><td>1.0</td><td>false</td></tr><tr><td>3.0</td><td>Venusaur</td><td>Grass</td><td>Poison</td><td>80.0</td><td>82.0</td><td>83.0</td><td>100.0</td><td>100.0</td><td>80.0</td><td>1.0</td><td>false</td></tr><tr><td>3.0</td><td>VenusaurMega Venusaur</td><td>Grass</td><td>Poison</td><td>80.0</td><td>100.0</td><td>123.0</td><td>122.0</td><td>120.0</td><td>80.0</td><td>1.0</td><td>false</td></tr><tr><td>4.0</td><td>Charmander</td><td>Fire</td><td>null</td><td>39.0</td><td>52.0</td><td>43.0</td><td>60.0</td><td>50.0</td><td>65.0</td><td>1.0</td><td>false</td></tr><tr><td>5.0</td><td>Charmeleon</td><td>Fire</td><td>null</td><td>58.0</td><td>64.0</td><td>58.0</td><td>80.0</td><td>65.0</td><td>80.0</td><td>1.0</td><td>false</td></tr><tr><td>6.0</td><td>Charizard</td><td>Fire</td><td>Flying</td><td>78.0</td><td>84.0</td><td>78.0</td><td>109.0</td><td>85.0</td><td>100.0</td><td>1.0</td><td>false</td></tr><tr><td>6.0</td><td>CharizardMega Charizard X</td><td>Fire</td><td>Dragon</td><td>78.0</td><td>130.0</td><td>111.0</td><td>130.0</td><td>85.0</td><td>100.0</td><td>1.0</td><td>false</td></tr><tr><td>6.0</td><td>CharizardMega Charizard Y</td><td>Fire</td><td>Flying</td><td>78.0</td><td>104.0</td><td>78.0</td><td>159.0</td><td>115.0</td><td>100.0</td><td>1.0</td><td>false</td></tr><tr><td>7.0</td><td>Squirtle</td><td>Water</td><td>null</td><td>44.0</td><td>48.0</td><td>65.0</td><td>50.0</td><td>64.0</td><td>43.0</td><td>1.0</td><td>false</td></tr><tr><td>8.0</td><td>Wartortle</td><td>Water</td><td>null</td><td>59.0</td><td>63.0</td><td>80.0</td><td>65.0</td><td>80.0</td><td>58.0</td><td>1.0</td><td>false</td></tr><tr><td>9.0</td><td>Blastoise</td><td>Water</td><td>null</td><td>79.0</td><td>83.0</td><td>100.0</td><td>85.0</td><td>105.0</td><td>78.0</td><td>1.0</td><td>false</td></tr><tr><td>9.0</td><td>BlastoiseMega Blastoise</td><td>Water</td><td>null</td><td>79.0</td><td>103.0</td><td>120.0</td><td>135.0</td><td>115.0</td><td>78.0</td><td>1.0</td><td>false</td></tr><tr><td>10.0</td><td>Caterpie</td><td>Bug</td><td>null</td><td>45.0</td><td>30.0</td><td>35.0</td><td>20.0</td><td>20.0</td><td>45.0</td><td>1.0</td><td>false</td></tr><tr><td>11.0</td><td>Metapod</td><td>Bug</td><td>null</td><td>50.0</td><td>20.0</td><td>55.0</td><td>25.0</td><td>25.0</td><td>30.0</td><td>1.0</td><td>false</td></tr><tr><td>12.0</td><td>Butterfree</td><td>Bug</td><td>Flying</td><td>60.0</td><td>45.0</td><td>50.0</td><td>90.0</td><td>80.0</td><td>70.0</td><td>1.0</td><td>false</td></tr><tr><td>13.0</td><td>Weedle</td><td>Bug</td><td>Poison</td><td>40.0</td><td>35.0</td><td>30.0</td><td>20.0</td><td>20.0</td><td>50.0</td><td>1.0</td><td>false</td></tr><tr><td>14.0</td><td>Kakuna</td><td>Bug</td><td>Poison</td><td>45.0</td><td>25.0</td><td>50.0</td><td>25.0</td><td>25.0</td><td>35.0</td><td>1.0</td><td>false</td></tr><tr><td>15.0</td><td>Beedrill</td><td>Bug</td><td>Poison</td><td>65.0</td><td>90.0</td><td>40.0</td><td>45.0</td><td>80.0</td><td>75.0</td><td>1.0</td><td>false</td></tr><tr><td>15.0</td><td>BeedrillMega Beedrill</td><td>Bug</td><td>Poison</td><td>65.0</td><td>150.0</td><td>40.0</td><td>15.0</td><td>80.0</td><td>145.0</td><td>1.0</td><td>false</td></tr><tr><td>16.0</td><td>Pidgey</td><td>Normal</td><td>Flying</td><td>40.0</td><td>45.0</td><td>40.0</td><td>35.0</td><td>35.0</td><td>56.0</td><td>1.0</td><td>false</td></tr><tr><td>17.0</td><td> ...

# %%
df1 = df.filter("Type 1" == 'Fire')
df1.display()
# Out:
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# File <command-3684146070111795>:1
# ----> 1 df1 = df.filter("Type 1" == 'Fire')
#       2 df1.display()
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/dataframe.py:3127, in DataFrame.filter(self, condition)
#    3125     jdf = self._jdf.filter(condition._jc)
#    3126 else:
# -> 3127     raise PySparkTypeError(
#    3128         error_class="NOT_COLUMN_OR_STRING",
#    3129         message_parameters={"arg_name": "condition", "arg_type": type(condition).__name__},
#    3130     )
#    3131 return DataFrame(jdf, self.sparkSession)
#
# PySparkTypeError: [NOT_COLUMN_OR_STRING] Argument `condition` should be a Column or str, got bool.
